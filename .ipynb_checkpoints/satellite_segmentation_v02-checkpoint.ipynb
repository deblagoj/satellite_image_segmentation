# %% [markdown]
# # Notes
#
# VERY IMPORTANT¶
# without allow_growth GPU don't work
#
# https://towardsdatascience.com/understanding-binary-cross-entropy-log-loss-a-visual-explanation-a3ac6025181a
#
#
#
# https://github.com/tensorflow/tensorflow/issues/24496
#
# to install: conda install -c anaconda tensorflow-gpu
#
# apt-get install -y libsm6 libxext6 libxrender-dev pip install opencv-python
#
# pip install keras-segmentation
#
# gpustat -cp

# %% [markdown]
# # Links
#
# https://keras.io/examples/vision/oxford_pets_image_segmentation/
#
#
# https://www.kaggle.com/bulentsiyah/deep-learning-based-semantic-segmentation-keras
#
# https://www.kaggle.com/ianmoone0617/aerial-drone-semantic-image-segmentation-fastai
#
#
# https://divamgupta.com/image-segmentation/2019/06/06/deep-learning-semantic-segmentation-keras.html
#
#
# https://github.com/divamgupta/image-segmentation-keras

# %% [markdown]
# ## activate this conda env
#
# conda activate tf-gpu4

# %% [markdown]
# # VERY IMPORTANT
#
# without allow_growth GPU don't work
#
# https://github.com/tensorflow/tensorflow/issues/24496
#
# to install:
# conda install -c anaconda tensorflow-gpu
#
#
# apt-get install -y libsm6 libxext6 libxrender-dev
# pip install opencv-python
#
# pip install keras-segmentation

# %% [markdown]
# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession
#
# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config)

# %% [markdown]
# ## Prepare paths of input images and target segmentation masks

# %%
import pandas as pd

# %%
from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
import PIL
from PIL import ImageOps
from PIL import Image

train_input_dir = "../dataset/images_prepared_train/"
train_target_dir = "../dataset/annotation_prepared_train/"



img_size = (224, 224)
num_classes = 9
batch_size = 32

import os

train_input_img_paths = sorted(
    [
        os.path.join(train_input_dir, fname)
        for fname in os.listdir(train_input_dir)
        if fname.endswith(".png")
    ]
)
train_target_img_paths = sorted(
    [
        os.path.join(train_target_dir, fname)
        for fname in os.listdir(train_target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)


print("Number of samples train:", len(train_input_img_paths))

for input_path, target_path in zip(train_input_img_paths[:10], train_target_img_paths[:10]):
    print(input_path, "|", target_path)
# Out:
# Number of samples train: 5159
# ../dataset/images_prepared_train/0.png | ../dataset/annotation_prepared_train/0.png
# ../dataset/images_prepared_train/1.png | ../dataset/annotation_prepared_train/1.png
# ../dataset/images_prepared_train/10.png | ../dataset/annotation_prepared_train/10.png
# ../dataset/images_prepared_train/1000.png | ../dataset/annotation_prepared_train/1000.png
# ../dataset/images_prepared_train/1001.png | ../dataset/annotation_prepared_train/1001.png
# ../dataset/images_prepared_train/1002.png | ../dataset/annotation_prepared_train/1002.png
# ../dataset/images_prepared_train/1003.png | ../dataset/annotation_prepared_train/1003.png
# ../dataset/images_prepared_train/1004.png | ../dataset/annotation_prepared_train/1004.png
# ../dataset/images_prepared_train/1005.png | ../dataset/annotation_prepared_train/1005.png
# ../dataset/images_prepared_train/1006.png | ../dataset/annotation_prepared_train/1006.png

# %% [raw]
# from IPython.display import Image, display
# from tensorflow.keras.preprocessing.image import load_img
# import PIL
# from PIL import ImageOps
# from PIL import Image
#
# for i in train_input_img_paths:
#     t=Image.open(i)
#     if(t.size)!=(224, 224):
#         print(i)
#         os.remove(i)
# for i in train_target_img_paths:
#     t=Image.open(i)
#     if(t.size)!=(224, 224):
#         print(i)
#         os.remove(i)

# %% [markdown]
# ## What does one input image and corresponding segmentation mask look like?

# %%
from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
import PIL
from PIL import ImageOps

# Display input image #7
display(Image(filename=train_input_img_paths[111]))

# Display auto-contrast version of corresponding target (per-pixel categories)
img = PIL.ImageOps.autocontrast(load_img(train_target_img_paths[111]))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F5A179AD950>

# %% [markdown]
# ## Prepare Sequence class to load & vectorize batches of data

# %% [raw]
# import numpy as np
# from keras.preprocessing.image import load_img
# import warnings
# from keras.preprocessing.image import img_to_array
# from keras.preprocessing.image import array_to_img
# from PIL import Image
#
# train_input_dat= np.array([np.array(Image.open(fname)) for fname in train_input_img_paths])
# train_target_dat1= np.array([np.array(Image.open(fname)) for fname in train_target_img_paths])
#
# train_target_dat = np.zeros(train_target_dat1.shape +  (9,), dtype=np.int)
# for q in range(9):
#     tmp = train_target_dat[:,:,:,q]
#     tmp[train_target_dat1==q] = 1
#     train_target_dat[:,:,:,q] = tmp
# print(train_target_dat.shape)
#
# np.save('train_input_dat', train_input_dat)
# np.save('train_target_dat', train_target_dat)

# %% [markdown]
# ## Import the model from Keras

# %% [raw]
# # from keras_segmentation.models.unet import vgg_unet
# from tensorflow.keras import layers
#
# model = vgg_unet(n_classes=9 ,  input_height=224, input_width=224  )
#
# model.summary()

# %% [markdown]
# ## Perpare U-Net Xception-style model

# %%
from tensorflow.keras import layers
import keras

def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model


# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
num_classes=9
model = get_model(img_size, num_classes)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# ## Read dataset

# %% [markdown]
# https://keras.io/api/metrics/segmentation_metrics/#image-segmentation-metrics

# %%
import numpy as np
input_dat = np.load(os.path.join('train_input_dat.npy'))
target_dat = np.load(os.path.join('train_target_dat.npy'))

# %% [markdown]
# ## split dataset for train and validation

# %%
train_input_dat=input_dat[1500:,:,:,:]
train_target_dat=target_dat[1500:,:,:,:]

val_input_dat=input_dat[:1500,:,:,:]
val_target_dat=target_dat[:1500,:,:,:]

# %% [raw]
# #Configure the model for training.
# # We use the "sparse" version of categorical_crossentropy
# # because our target data is integers.
#
# #
# import tensorflow as tf1
#
# model.compile(
#   optimizer='sgd',
#   loss='mse',
#   metrics=[tf.keras.metrics.CategoricalCrossentropy()]
# )
#
#
# callbacks = [
#     keras.callbacks.ModelCheckpoint("satellite_segmentation.h5", save_best_only=True)
# ]
#
# # Train the model, doing validation at the end of each epoch.
# epochs = 5
# history=model.fit(train_input_dat, train_target_dat, epochs=epochs, validation_data=(val_input_dat,val_target_dat), callbacks=callbacks)

# %%
history.history
# Out:
# {'loss': [0.09455379843711853,
#   0.09105119854211807,
#   0.08867331594228745,
#   0.08660995215177536,
#   0.08484185487031937,
#   0.08341249078512192,
#   0.08195676654577255,
#   0.08080682158470154,
#   0.07959398627281189,
#   0.07880125939846039,
#   0.07796642929315567,
#   0.07679896056652069,
#   0.07613828033208847,
#   0.0752744972705841,
#   0.07451393455266953,
#   0.07395460456609726,
#   0.07340975105762482,
#   0.07270380854606628,
#   0.07229873538017273,
#   0.07183321565389633,
#   0.07148271799087524,
#   0.0709550529718399,
#   0.0707259550690651,
#   0.07018733024597168,
#   0.069887176156044,
#   0.06947484612464905,
#   0.06914898008108139,
#   0.06887654215097427,
#   0.06854160875082016,
#   0.06848526746034622,
#   0.06812437623739243,
#   0.06773028522729874,
#   0.06740809231996536,
#   0.06722886860370636,
#   0.06705363839864731,
#   0.0668259710073471,
#   0.06648030877113342,
#   0.06641288846731186,
#   0.06624354422092438,
# ...

# %%
import pandas as pd

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# save to json:  
hist_json_file = 'history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv: 
hist_csv_file = 'history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
df=pd.read_csv('history.csv')
df
# Out:
#     Unnamed: 0      loss  categorical_crossentropy  val_loss  \
# 0            0  0.094554                  2.882064  0.179801
# 1            1  0.091051                  2.729362  0.143865
# 2            2  0.088673                  2.600732  0.098903
# 3            3  0.086610                  2.487847  0.087848
# 4            4  0.084842                  2.387154  0.085946
# 5            5  0.083412                  2.308131  0.084957
# 6            6  0.081957                  2.222432  0.083819
# 7            7  0.080807                  2.153667  0.082745
# 8            8  0.079594                  2.087676  0.081702
# 9            9  0.078801                  2.038572  0.080854
# 10          10  0.077966                  1.992509  0.079675
# 11          11  0.076799                  1.943636  0.078704
# 12          12  0.076138                  1.902837  0.077929
# 13          13  0.075274                  1.867856  0.077203
# ...

# %% [markdown]
# ## Evaluate model

# %% [markdown]
# ## Visualizing model performance
# ### Let's plot the model accuracy and loss for the training and the validating set. Note that no random seed is specified for this notebook. For your notebook, there might be slight variance.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'categorical_crossentropy']):
    ax[i].plot(df['loss'])
    ax[i].plot(df["val_" + met])
    ax[i].set_title("Model {}".format(met))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(met)
    ax[i].legend(["train", "val"])

# %% [markdown]
# ## Confution matrix
#
# https://gist.github.com/RyanAkilos/3808c17f79e77c4117de35aa68447045

# %%
Y_pred = model.predict_generator((val_input_dat,val_target_dat), 1500 // batch_size+1)

# %%
#Confution Matrix and Classification Report
Y_pred = model.predict_generator((val_input_dat,val_target_dat), 1500 // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = ['1', '2', '3', '4', '5','6','7','8','9']
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-185d24ba652a> in <module>
#       1 #Confution Matrix and Classification Report
# ----> 2 Y_pred = model.predict_generator(val_gen, len(val_input_img_paths) // batch_size+1)
#       3 y_pred = np.argmax(Y_pred, axis=1)
#       4 print('Confusion Matrix')
#       5 print(confusion_matrix(validation_generator.classes, y_pred))
#
# NameError: name 'val_gen' is not defined

# %% [markdown]
# ## Model Evaluate

# %%
model.evaluate(train_input_dat, train_target_dat,)

# %% [markdown]
# ## Visualize predictions

# %%
# Generate predictions for all images in the validation set

val_gen = Satellite_Images(batch_size, img_size, val_input_img_paths, val_target_img_paths)
val_preds = model.predict(val_gen)


def display_mask(i):
    """Quick utility to display a model's prediction."""
    mask = np.argmax(val_preds[i], axis=-1)
    mask = np.expand_dims(mask, axis=-1)
    img = PIL.ImageOps.autocontrast(keras.preprocessing.image.array_to_img(mask))
    display(img)


model.evaluate(val_gen)
    
    
# Display results for validation image #10
i = 110

# Display input image
display(Image(filename=val_input_img_paths[i]))

# Display ground-truth target mask
img = PIL.ImageOps.autocontrast(load_img(val_target_img_paths[i]))
display(img)

# Display mask predicted by our model
display_mask(i)  # Note that the model only sees inputs at 150x150.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-dde8d4c62c65> in <module>
#       1 # Generate predictions for all images in the validation set
#       2
# ----> 3 val_gen = Satellite_Images(batch_size, img_size, val_input_img_paths, val_target_img_paths)
#       4 val_preds = model.predict(val_gen)
#       5
#
# NameError: name 'Satellite_Images' is not defined

# %%
# Split our img paths into a training and a validation set
val_samples = 1000
random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_img_paths)
train_input_img_paths = input_img_paths[:-val_samples]
train_target_img_paths = target_img_paths[:-val_samples]
val_input_img_paths = input_img_paths[-val_samples:]
val_target_img_paths = target_img_paths[-val_samples:]
