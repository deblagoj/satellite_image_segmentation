# %% [markdown]
# ## Read dataset

# %%
import numpy as np
import os
from tensorflow.keras import layers
import keras
from PIL import Image
import numpy as np
import copy
import matplotlib.pyplot as plt
import tensorflow as tf

import PIL
from PIL import ImageOps
from PIL import Image

# %%
input_dat = np.load(os.path.join('../data_fin/train_input_dat.npy'))
target_dat = np.load(os.path.join('../data_fin/train_target_dat.npy'))

# %%
train_input_dat=input_dat[1500:,:,:,:]
train_target_dat=target_dat[1500:,:,:,:]

val_input_dat=input_dat[:1500,:,:,:]
val_target_dat=target_dat[:1500,:,:,:]

# %%
from matplotlib.colors import LinearSegmentedColormap, BoundaryNorm
def Setcmap(D, inv=1):
    cmap = plt.cm.jet
    cmaplist = [cmap(i) for i in range(cmap.N)]
    cmaplist[0] = (.0, .0, .0, 1.0)
    if inv:
        cmap = LinearSegmentedColormap.from_list('Custom_cmap', cmaplist, cmap.N)
    else:
        cmap = LinearSegmentedColormap.from_list('Custom_cmap', cmaplist[::-1], cmap.N)
    plt.register_cmap(name='Custom_cmap', cmap=cmap)
    bounds = np.linspace(0, D, D+1)
    norm = BoundaryNorm(bounds, cmap.N)
    return cmap, norm



def display_image(I):
    print(I.shape)
    tmp = np.zeros((I.shape[0], I.shape[1], 3), dtype=np.uint8)
    for q in range(3):
        a = copy.copy(I[:,:,q]) 
        D = a>0
        prc = np.percentile(a[D],[1,99])
        tmp[:,:,2-q] = np.digitize(a,np.linspace(prc[0],prc[1],255))*D
    plt.imshow(tmp)
    f = plt.gcf()
    f.set_size_inches(15, 14)
    plt.show()
    
def display_target(I):
    cmap, norm = Setcmap(9)
    Class=np.argmax(I, axis=-1)
    im = plt.imshow(Class, cmap=cmap, norm=norm, vmin=0, vmax=9)
    plt.title('Classification')
    plt.set_cmap(cmap)
    cb = plt.colorbar(im, fraction=0.046, pad=0.04, ticks=range(9))
    cb.set_ticks(np.arange(9) + .5)
    cb.set_ticklabels(np.arange(9))
    plt.gcf().set_size_inches(15, 14)
    plt.show()
    
    
    
    
# Display results for validation image #10
i = 78


# Display input image
display_image(val_input_dat[i])

# Display ground-truth target mask
display_target(val_target_dat[i])
# Out:
# (224, 224, 3)
# /home/bd/anaconda3/envs/tf-gpu4/lib/python3.7/site-packages/ipykernel_launcher.py:33: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# ## Perpare U-Net Xception-style model

# %%
img_size = (224, 224)
num_classes = 9
batch_size = 32

def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model


# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
num_classes=9
model = get_model(img_size, num_classes)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 32) 0           activation[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 112, 112, 64) 2400        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 64) 256         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 112, 112, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 112, 112, 64) 4736        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 112, 112, 64) 256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 64)   0           max_pooling2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 56, 56, 128)  8896        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 128)  512         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 56, 56, 128)  17664       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 128)  512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 128)  8320        add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 128)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 28, 28, 256)  34176       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 256)  1024        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 28, 28, 256)  68096       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 256)  1024        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 256)  33024       add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 256)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 14, 14, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 256)  1024        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 14, 14, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 256)  1024        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 28, 28, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 28, 28, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 256)  65792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 256)  0           up_sampling2d[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 28, 28, 128)  295040      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 128)  512         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 28, 28, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 128)  512         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 56, 56, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 56, 56, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  32896       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 56, 56, 128)  0           up_sampling2d_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 56, 56, 64)   73792       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 64)   256         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 56, 56, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 64)   256         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 112, 112, 128 0           add_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 112, 112, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 64) 8256        up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 112, 112, 64) 0           up_sampling2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 112, 112, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 112, 112, 32) 18464       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 112, 112, 32) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 112, 112, 32) 9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 224, 224, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 224, 224, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 224, 224, 32) 2080        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 224, 224, 32) 0           up_sampling2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 224, 224, 9)  2601        add_6[0][0]
# ==================================================================================================
# Total params: 2,060,713
# Trainable params: 2,056,937
# Non-trainable params: 3,776
# __________________________________________________________________________________________________

# %% [markdown]
# https://keras.io/api/metrics/segmentation_metrics/#image-segmentation-metrics

# %% [markdown]
# ## Train

# %%
#Configure the model for training.
# We use the "sparse" version of categorical_crossentropy
# because our target data is integers.
  
#  

model.compile(
  optimizer='sgd',
  loss='mse',
  metrics=[tf.keras.metrics.CategoricalCrossentropy()]
)

callbacks = [
    keras.callbacks.ModelCheckpoint("satellite_segmentation-v001.h5", save_best_only=True)
]

# Train the model, doing validation at the end of each epoch.
epochs = 100
history=model.fit(train_input_dat, train_target_dat, epochs=epochs, 
                  validation_data=(val_input_dat,val_target_dat), callbacks=callbacks)
# Out:
# Epoch 1/100
#   2/115 [..............................] - ETA: 19s - loss: 0.1562 - categorical_crossentropy: 6.3756WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1148s vs `on_train_batch_end` time: 0.1885s). Check your callbacks.
# 115/115 [==============================] - 219s 2s/step - loss: 0.1206 - categorical_crossentropy: 4.5476 - val_loss: 0.1286 - val_categorical_crossentropy: 3.2323
# Epoch 2/100
# 115/115 [==============================] - 38s 333ms/step - loss: 0.1025 - categorical_crossentropy: 3.4313 - val_loss: 0.1683 - val_categorical_crossentropy: 4.9563
# Epoch 3/100
# 115/115 [==============================] - 37s 323ms/step - loss: 0.0956 - categorical_crossentropy: 3.1286 - val_loss: 0.1753 - val_categorical_crossentropy: 5.5606
# Epoch 4/100
# 115/115 [==============================] - 37s 324ms/step - loss: 0.0924 - categorical_crossentropy: 2.9913 - val_loss: 0.1543 - val_categorical_crossentropy: 4.0161
# Epoch 5/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0902 - categorical_crossentropy: 2.8699 - val_loss: 0.0894 - val_categorical_crossentropy: 2.2201
# Epoch 6/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0882 - categorical_crossentropy: 2.7598 - val_loss: 0.0800 - val_categorical_crossentropy: 2.2165
# Epoch 7/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0864 - categorical_crossentropy: 2.6588 - val_loss: 0.0794 - val_categorical_crossentropy: 2.3742
# Epoch 8/100
# 115/115 [==============================] - 38s 326ms/step - loss: 0.0850 - categorical_crossentropy: 2.5693 - val_loss: 0.0788 - val_categorical_crossentropy: 2.3466
# Epoch 9/100
# 115/115 [==============================] - 37s 325ms/step - loss: 0.0837 - categorical_crossentropy: 2.4909 - val_loss: 0.0780 - val_categorical_crossentropy: 2.3523
# Epoch 10/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0823 - categorical_crossentropy: 2.4133 - val_loss: 0.0772 - val_categorical_crossentropy: 2.2698
# Epoch 11/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0811 - categorical_crossentropy: 2.3419 - val_loss: 0.0764 - val_categorical_crossentropy: 2.2229
# Epoch 12/100
# 115/115 [==============================] - 40s 349ms/step - loss: 0.0802 - categorical_crossentropy: 2.2805 - val_loss: 0.0750 - val_categorical_crossentropy: 2.1345
# Epoch 13/100
# 115/115 [==============================] - 40s 351ms/step - loss: 0.0793 - categorical_crossentropy: 2.2195 - val_loss: 0.0742 - val_categorical_crossentropy: 2.0858
# Epoch 14/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0783 - categorical_crossentropy: 2.1576 - val_loss: 0.0733 - val_categorical_crossentropy: 2.0352
# Epoch 15/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0773 - categorical_crossentropy: 2.0982 - val_loss: 0.0727 - val_categorical_crossentropy: 1.9920
# Epoch 16/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0768 - categorical_crossentropy: 2.0560 - val_loss: 0.0719 - val_categorical_crossentropy: 1.9441
# Epoch 17/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0762 - categorical_crossentropy: 2.0099 - val_loss: 0.0712 - val_categorical_crossentropy: 1.8860
# Epoch 18/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0754 - categorical_crossentropy: 1.9654 - val_loss: 0.0710 - val_categorical_crossentropy: 1.8713
# Epoch 19/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0749 - categorical_crossentropy: 1.9253 - val_loss: 0.0705 - val_categorical_crossentropy: 1.8241
# Epoch 20/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0742 - categorical_crossentropy: 1.8829 - val_loss: 0.0694 - val_categorical_crossentropy: 1.7612
# Epoch 21/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0737 - categorical_crossentropy: 1.8493 - val_loss: 0.0689 - val_categorical_crossentropy: 1.7478
# Epoch 22/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0733 - categorical_crossentropy: 1.8189 - val_loss: 0.0684 - val_categorical_crossentropy: 1.7053
# Epoch 23/100
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0727 - categorical_crossentropy: 1.7839 - val_loss: 0.0681 - val_categorical_crossentropy: 1.6781
# Epoch 24/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0723 - categorical_crossentropy: 1.7524 - val_loss: 0.0688 - val_categorical_crossentropy: 1.6727
# Epoch 25/100
# 115/115 [==============================] - 38s 333ms/step - loss: 0.0719 - categorical_crossentropy: 1.7244 - val_loss: 0.0671 - val_categorical_crossentropy: 1.6135
# Epoch 26/100
# 115/115 [==============================] - 38s 333ms/step - loss: 0.0716 - categorical_crossentropy: 1.7081 - val_loss: 0.0667 - val_categorical_crossentropy: 1.6006
# Epoch 27/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0713 - categorical_crossentropy: 1.6869 - val_loss: 0.0666 - val_categorical_crossentropy: 1.5897
# Epoch 28/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0706 - categorical_crossentropy: 1.6566 - val_loss: 0.0662 - val_categorical_crossentropy: 1.5663
# Epoch 29/100
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0705 - categorical_crossentropy: 1.6434 - val_loss: 0.0657 - val_categorical_crossentropy: 1.5423
# Epoch 30/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0701 - categorical_crossentropy: 1.6189 - val_loss: 0.0653 - val_categorical_crossentropy: 1.5186
# Epoch 31/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0697 - categorical_crossentropy: 1.6028 - val_loss: 0.0651 - val_categorical_crossentropy: 1.5040
# Epoch 32/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0696 - categorical_crossentropy: 1.5881 - val_loss: 0.0650 - val_categorical_crossentropy: 1.4940
# Epoch 33/100
# 115/115 [==============================] - 38s 333ms/step - loss: 0.0691 - categorical_crossentropy: 1.5682 - val_loss: 0.0646 - val_categorical_crossentropy: 1.4827
# Epoch 34/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0689 - categorical_crossentropy: 1.5622 - val_loss: 0.0647 - val_categorical_crossentropy: 1.4795
# Epoch 35/100
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0688 - categorical_crossentropy: 1.5498 - val_loss: 0.0642 - val_categorical_crossentropy: 1.4580
# Epoch 36/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0684 - categorical_crossentropy: 1.5331 - val_loss: 0.0638 - val_categorical_crossentropy: 1.4402
# Epoch 37/100
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0682 - categorical_crossentropy: 1.5221 - val_loss: 0.0634 - val_categorical_crossentropy: 1.4231
# Epoch 38/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0680 - categorical_crossentropy: 1.5106 - val_loss: 0.0632 - val_categorical_crossentropy: 1.4160
# Epoch 39/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0679 - categorical_crossentropy: 1.5044 - val_loss: 0.0638 - val_categorical_crossentropy: 1.4241
# Epoch 40/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0676 - categorical_crossentropy: 1.4924 - val_loss: 0.0633 - val_categorical_crossentropy: 1.4013
# Epoch 41/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0675 - categorical_crossentropy: 1.4842 - val_loss: 0.0629 - val_categorical_crossentropy: 1.3971
# Epoch 42/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0672 - categorical_crossentropy: 1.4718 - val_loss: 0.0631 - val_categorical_crossentropy: 1.4021
# Epoch 43/100
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0670 - categorical_crossentropy: 1.4638 - val_loss: 0.0623 - val_categorical_crossentropy: 1.3718
# Epoch 44/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0669 - categorical_crossentropy: 1.4582 - val_loss: 0.0621 - val_categorical_crossentropy: 1.3657
# Epoch 45/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0667 - categorical_crossentropy: 1.4531 - val_loss: 0.0620 - val_categorical_crossentropy: 1.3643
# Epoch 46/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0665 - categorical_crossentropy: 1.4422 - val_loss: 0.0623 - val_categorical_crossentropy: 1.3606
# Epoch 47/100
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0663 - categorical_crossentropy: 1.4358 - val_loss: 0.0619 - val_categorical_crossentropy: 1.3492
# Epoch 48/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0663 - categorical_crossentropy: 1.4335 - val_loss: 0.0620 - val_categorical_crossentropy: 1.3545
# Epoch 49/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0663 - categorical_crossentropy: 1.4289 - val_loss: 0.0614 - val_categorical_crossentropy: 1.3375
# Epoch 50/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0659 - categorical_crossentropy: 1.4178 - val_loss: 0.0614 - val_categorical_crossentropy: 1.3351
# Epoch 51/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0657 - categorical_crossentropy: 1.4122 - val_loss: 0.0613 - val_categorical_crossentropy: 1.3303
# Epoch 52/100
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0658 - categorical_crossentropy: 1.4127 - val_loss: 0.0610 - val_categorical_crossentropy: 1.3211
# Epoch 53/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0656 - categorical_crossentropy: 1.4062 - val_loss: 0.0610 - val_categorical_crossentropy: 1.3142
# Epoch 54/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0654 - categorical_crossentropy: 1.4011 - val_loss: 0.0607 - val_categorical_crossentropy: 1.3075
# Epoch 55/100
# 115/115 [==============================] - 37s 325ms/step - loss: 0.0655 - categorical_crossentropy: 1.3997 - val_loss: 0.0609 - val_categorical_crossentropy: 1.3124
# Epoch 56/100
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0652 - categorical_crossentropy: 1.3923 - val_loss: 0.0607 - val_categorical_crossentropy: 1.3053
# Epoch 57/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0651 - categorical_crossentropy: 1.3892 - val_loss: 0.0605 - val_categorical_crossentropy: 1.2996
# Epoch 58/100
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0649 - categorical_crossentropy: 1.3821 - val_loss: 0.0605 - val_categorical_crossentropy: 1.2994
# Epoch 59/100
# 115/115 [==============================] - 37s 324ms/step - loss: 0.0650 - categorical_crossentropy: 1.3827 - val_loss: 0.0606 - val_categorical_crossentropy: 1.2982
# Epoch 60/100
# 115/115 [==============================] - 37s 325ms/step - loss: 0.0648 - categorical_crossentropy: 1.3775 - val_loss: 0.0608 - val_categorical_crossentropy: 1.3082
# Epoch 61/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0646 - categorical_crossentropy: 1.3721 - val_loss: 0.0603 - val_categorical_crossentropy: 1.2871
# Epoch 62/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0646 - categorical_crossentropy: 1.3720 - val_loss: 0.0600 - val_categorical_crossentropy: 1.2839
# Epoch 63/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0646 - categorical_crossentropy: 1.3697 - val_loss: 0.0602 - val_categorical_crossentropy: 1.2885
# Epoch 64/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0644 - categorical_crossentropy: 1.3622 - val_loss: 0.0598 - val_categorical_crossentropy: 1.2722
# Epoch 65/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0644 - categorical_crossentropy: 1.3649 - val_loss: 0.0599 - val_categorical_crossentropy: 1.2787
# Epoch 66/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0643 - categorical_crossentropy: 1.3603 - val_loss: 0.0601 - val_categorical_crossentropy: 1.2796
# Epoch 67/100
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0642 - categorical_crossentropy: 1.3555 - val_loss: 0.0596 - val_categorical_crossentropy: 1.2674
# Epoch 68/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0643 - categorical_crossentropy: 1.3576 - val_loss: 0.0603 - val_categorical_crossentropy: 1.2878
# Epoch 69/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0640 - categorical_crossentropy: 1.3511 - val_loss: 0.0608 - val_categorical_crossentropy: 1.2986
# Epoch 70/100
# 115/115 [==============================] - 38s 333ms/step - loss: 0.0641 - categorical_crossentropy: 1.3515 - val_loss: 0.0593 - val_categorical_crossentropy: 1.2598
# Epoch 71/100
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0638 - categorical_crossentropy: 1.3445 - val_loss: 0.0592 - val_categorical_crossentropy: 1.2580
# Epoch 72/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0639 - categorical_crossentropy: 1.3465 - val_loss: 0.0592 - val_categorical_crossentropy: 1.2550
# Epoch 73/100
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0637 - categorical_crossentropy: 1.3410 - val_loss: 0.0591 - val_categorical_crossentropy: 1.2489
# Epoch 74/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0638 - categorical_crossentropy: 1.3418 - val_loss: 0.0594 - val_categorical_crossentropy: 1.2605
# Epoch 75/100
# 115/115 [==============================] - 38s 326ms/step - loss: 0.0637 - categorical_crossentropy: 1.3396 - val_loss: 0.0591 - val_categorical_crossentropy: 1.2560
# Epoch 76/100
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0635 - categorical_crossentropy: 1.3336 - val_loss: 0.0589 - val_categorical_crossentropy: 1.2476
# Epoch 77/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0636 - categorical_crossentropy: 1.3361 - val_loss: 0.0588 - val_categorical_crossentropy: 1.2418
# Epoch 78/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0634 - categorical_crossentropy: 1.3310 - val_loss: 0.0594 - val_categorical_crossentropy: 1.2556
# Epoch 79/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0634 - categorical_crossentropy: 1.3305 - val_loss: 0.0593 - val_categorical_crossentropy: 1.2575
# Epoch 80/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0633 - categorical_crossentropy: 1.3284 - val_loss: 0.0586 - val_categorical_crossentropy: 1.2359
# Epoch 81/100
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0634 - categorical_crossentropy: 1.3294 - val_loss: 0.0585 - val_categorical_crossentropy: 1.2357
# Epoch 82/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0632 - categorical_crossentropy: 1.3252 - val_loss: 0.0585 - val_categorical_crossentropy: 1.2334
# Epoch 83/100
# 115/115 [==============================] - 37s 325ms/step - loss: 0.0631 - categorical_crossentropy: 1.3206 - val_loss: 0.0584 - val_categorical_crossentropy: 1.2334
# Epoch 84/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0631 - categorical_crossentropy: 1.3228 - val_loss: 0.0584 - val_categorical_crossentropy: 1.2323
# Epoch 85/100
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0632 - categorical_crossentropy: 1.3223 - val_loss: 0.0582 - val_categorical_crossentropy: 1.2264
# Epoch 86/100
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0630 - categorical_crossentropy: 1.3194 - val_loss: 0.0582 - val_categorical_crossentropy: 1.2244
# Epoch 87/100
# 115/115 [==============================] - 38s 326ms/step - loss: 0.0629 - categorical_crossentropy: 1.3152 - val_loss: 0.0588 - val_categorical_crossentropy: 1.2400
# Epoch 88/100
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0630 - categorical_crossentropy: 1.3174 - val_loss: 0.0582 - val_categorical_crossentropy: 1.2233
# Epoch 89/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0628 - categorical_crossentropy: 1.3136 - val_loss: 0.0582 - val_categorical_crossentropy: 1.2235
# Epoch 90/100
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0628 - categorical_crossentropy: 1.3120 - val_loss: 0.0580 - val_categorical_crossentropy: 1.2170
# Epoch 91/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0626 - categorical_crossentropy: 1.3084 - val_loss: 0.0579 - val_categorical_crossentropy: 1.2186
# Epoch 92/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0627 - categorical_crossentropy: 1.3100 - val_loss: 0.0589 - val_categorical_crossentropy: 1.2432
# Epoch 93/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0625 - categorical_crossentropy: 1.3065 - val_loss: 0.0579 - val_categorical_crossentropy: 1.2140
# Epoch 94/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0626 - categorical_crossentropy: 1.3073 - val_loss: 0.0579 - val_categorical_crossentropy: 1.2155
# Epoch 95/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0625 - categorical_crossentropy: 1.3038 - val_loss: 0.0582 - val_categorical_crossentropy: 1.2186
# Epoch 96/100
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0626 - categorical_crossentropy: 1.3055 - val_loss: 0.0577 - val_categorical_crossentropy: 1.2143
# Epoch 97/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0624 - categorical_crossentropy: 1.3021 - val_loss: 0.0576 - val_categorical_crossentropy: 1.2082
# Epoch 98/100
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0624 - categorical_crossentropy: 1.3032 - val_loss: 0.0577 - val_categorical_crossentropy: 1.2127
# Epoch 99/100
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0623 - categorical_crossentropy: 1.2996 - val_loss: 0.0575 - val_categorical_crossentropy: 1.2053
# Epoch 100/100
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0624 - categorical_crossentropy: 1.3014 - val_loss: 0.0577 - val_categorical_crossentropy: 1.2056

# %%
import pandas as pd

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# or save to csv: 
hist_csv_file = 'history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %% [markdown]
# ## Evaluate model

# %% [markdown]
# ## Visualizing model performance
# ### Let's plot the model accuracy and loss for the training and the validating set. Note that no random seed is specified for this notebook. For your notebook, there might be slight variance.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'categorical_crossentropy']):
    ax[i].plot(df['loss'])
    ax[i].plot(df["val_" + met])
    ax[i].set_title("Model {}".format(met))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(met)
    ax[i].legend(["train", "val"])

# %%
model = get_model(img_size, num_classes)
model.summary()

fnmodel = 'weights/satellite_segmentation-v001.h5'
model.load_weights(filepath = fnmodel)
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 112, 112, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 112, 112, 32) 128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 112, 112, 32) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 112, 112, 32) 0           activation_30[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 112, 112, 64) 2400        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 112, 112, 64) 256         separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 112, 112, 64) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 112, 112, 64) 4736        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 112, 112, 64) 256         separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 56, 56, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 56, 56, 64)   2112        activation_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 56, 56, 64)   0           max_pooling2d_6[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 56, 56, 64)   0           add_14[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 56, 56, 128)  8896        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 56, 56, 128)  512         separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 56, 56, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 56, 56, 128)  17664       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 56, 56, 128)  512         separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 28, 28, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 128)  8320        add_14[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 28, 28, 128)  0           max_pooling2d_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 28, 28, 128)  0           add_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 28, 28, 256)  34176       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 28, 28, 256)  1024        separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 28, 28, 256)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_17 (SeparableC (None, 28, 28, 256)  68096       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 28, 28, 256)  1024        separable_conv2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 256)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 256)  33024       add_15[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 14, 14, 256)  0           max_pooling2d_8[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 256)  0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 14, 14, 256)  590080      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 14, 14, 256)  1024        conv2d_transpose_16[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 256)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 14, 14, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 14, 14, 256)  1024        conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 28, 28, 256)  0           add_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 28, 28, 256)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 256)  65792       up_sampling2d_17[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 28, 28, 256)  0           up_sampling2d_16[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 28, 28, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 28, 28, 128)  295040      activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 28, 28, 128)  512         conv2d_transpose_18[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 28, 28, 128)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 28, 28, 128)  147584      activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 28, 28, 128)  512         conv2d_transpose_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 56, 56, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 56, 56, 128)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 128)  32896       up_sampling2d_19[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 56, 56, 128)  0           up_sampling2d_18[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 56, 56, 128)  0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 56, 56, 64)   73792       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 56, 56, 64)   256         conv2d_transpose_20[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 56, 56, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 56, 56, 64)   36928       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 56, 56, 64)   256         conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 112, 112, 128 0           add_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 112, 112, 64) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 112, 112, 64) 8256        up_sampling2d_21[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 112, 112, 64) 0           up_sampling2d_20[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 112, 112, 64) 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 112, 112, 32) 18464       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_22[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 112, 112, 32) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 112, 112, 32) 9248        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_23[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 224, 224, 64) 0           add_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 224, 224, 32) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 224, 224, 32) 2080        up_sampling2d_23[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 224, 224, 32) 0           up_sampling2d_22[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 224, 224, 9)  2601        add_20[0][0]
# ==================================================================================================
# Total params: 2,060,713
# Trainable params: 2,056,937
# Non-trainable params: 3,776
# __________________________________________________________________________________________________

# %%
model

# %% [markdown]
# ## Confution matrix
#
# https://gist.github.com/RyanAkilos/3808c17f79e77c4117de35aa68447045

# %%
Y_pred = model.predict_generator((val_input_dat,val_target_dat), 1500 // batch_size+1)
y_pred= np.argmax(Y_pred, axis=3).flatten()
y= np.argmax(val_target_dat, axis=3).flatten()
# Out:
# WARNING:tensorflow:From <ipython-input-78-1949f9daf3d0>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
target_names=['1','2','3','4','5','6','7','8','9']

cm = confusion_matrix(y, y_pred)
# Normalise
cmn = cm.astype('float') /cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=target_names, yticklabels=target_names)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show(block=False)

# %% [markdown]
# ## Model Evaluate

# %% [markdown]
# ## Visualize predictions

# %%
Y_pred.shape
# Out:
# (1500, 224, 224, 9)

# %%
val_target_dat[i].shape
# Out:
# (224, 224, 9)

# %%
from matplotlib.colors import LinearSegmentedColormap, BoundaryNorm
def Setcmap(D, inv=1):
    cmap = plt.cm.jet
    cmaplist = [cmap(i) for i in range(cmap.N)]
    cmaplist[0] = (.0, .0, .0, 1.0)
    if inv:
        cmap = LinearSegmentedColormap.from_list('Custom_cmap', cmaplist, cmap.N)
    else:
        cmap = LinearSegmentedColormap.from_list('Custom_cmap', cmaplist[::-1], cmap.N)
    plt.register_cmap(name='Custom_cmap', cmap=cmap)
    bounds = np.linspace(0, D, D+1)
    norm = BoundaryNorm(bounds, cmap.N)
    return cmap, norm



def display_image(I):
    print(I.shape)
    tmp = np.zeros((I.shape[0], I.shape[1], 3), dtype=np.uint8)
    for q in range(3):
        a = copy.copy(I[:,:,q]) 
        D = a>0
        prc = np.percentile(a[D],[1,99])
        tmp[:,:,2-q] = np.digitize(a,np.linspace(prc[0],prc[1],255))*D
    plt.imshow(tmp)
    f = plt.gcf()
    f.set_size_inches(15, 14)
    plt.show()
    
def display_target(I):
    cmap, norm = Setcmap(9)
    Class=np.argmax(I, axis=-1)
    im = plt.imshow(Class, cmap=cmap, norm=norm, vmin=0, vmax=9)
    plt.title('Classification')
    plt.set_cmap(cmap)
    cb = plt.colorbar(im, fraction=0.046, pad=0.04, ticks=range(9))
    cb.set_ticks(np.arange(9) + .5)
    cb.set_ticklabels(np.arange(9))
    plt.gcf().set_size_inches(15, 14)
    plt.show()
    
# Display results for validation image #10
i = 12


# Display input image
display_image(val_input_dat[i])

# Display ground-truth target mask
display_target(val_target_dat[i])
# Display mask predicted by our model
#display_mask(i)  # Note that the model only sees inputs at 150x150.
display_target(Y_pred[i])
# Out:
# (224, 224, 3)
# /home/bd/anaconda3/envs/tf-gpu4/lib/python3.7/site-packages/ipykernel_launcher.py:33: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
